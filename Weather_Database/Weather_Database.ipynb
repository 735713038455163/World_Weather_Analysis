# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
from citipy import citipy
import json
import time
from scipy.stats import linregress
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 774

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# 2) Loop Through the List of Cities and Build the City URL
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
        
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    
    # Add 1 to the record count.
    record_count += 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | hakkari
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | bambous virieux
# Processing Record 10 of Set 1 | sao luiz gonzaga
# Processing Record 11 of Set 1 | port lincoln
# Processing Record 12 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 1 | pevek
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | constitucion
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | san andres
# Processing Record 21 of Set 1 | tocopilla
# Processing Record 22 of Set 1 | faanui
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | maturin
# Processing Record 25 of Set 1 | esperance
# Processing Record 26 of Set 1 | hojo
# Processing Record 27 of Set 1 | mangrol
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | manggar
# Processing Record 30 of Set 1 | cockburn town
# Processing Record 31 of Set 1 | saskylakh
# Processing Record 32 of Set 1 | mayo
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | smithers
# Processing Record 35 of Set 1 | port macquarie
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | walvis bay
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | husavik
# Processing Record 40 of Set 1 | caceres
# Processing Record 41 of Set 1 | dali
# Processing Record 42 of Set 1 | segou
# Processing Record 43 of Set 1 | lagoa
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | komsomolskiy
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | flic en flac
# Processing Record 50 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | merauke
# Processing Record 3 of Set 2 | tlahualilo
# City not found. Skipping...
# Processing Record 4 of Set 2 | bushehr
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | port hawkesbury
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 8 of Set 2 | yar-sale
# Processing Record 9 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 2 | rocha
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | mildura
# Processing Record 13 of Set 2 | slave lake
# Processing Record 14 of Set 2 | ambunti
# Processing Record 15 of Set 2 | port elizabeth
# Processing Record 16 of Set 2 | souillac
# Processing Record 17 of Set 2 | isangel
# Processing Record 18 of Set 2 | turbat
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | mitsamiouli
# Processing Record 22 of Set 2 | mabaruma
# Processing Record 23 of Set 2 | harper
# Processing Record 24 of Set 2 | pachino
# Processing Record 25 of Set 2 | ardakan
# Processing Record 26 of Set 2 | kangaatsiaq
# Processing Record 27 of Set 2 | mayor pablo lagerenza
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | zavodouspenskoye
# Processing Record 30 of Set 2 | sakakah
# Processing Record 31 of Set 2 | micheweni
# Processing Record 32 of Set 2 | boa vista
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | ngunguru
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | maues
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | quesnel
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | mogadishu
# Processing Record 42 of Set 2 | vardo
# Processing Record 43 of Set 2 | safford
# Processing Record 44 of Set 2 | sao joao da barra
# Processing Record 45 of Set 2 | juneau
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | bathsheba
# Processing Record 48 of Set 2 | jinka
# Processing Record 49 of Set 2 | grootfontein
# Processing Record 50 of Set 2 | mackay
# Processing Record 1 of Set 3 | umm kaddadah
# Processing Record 2 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 3 | port hardy
# Processing Record 4 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | road town
# Processing Record 7 of Set 3 | balkhash
# Processing Record 8 of Set 3 | high level
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 3 | yandyki
# Processing Record 11 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | carnarvon
# Processing Record 14 of Set 3 | sibu
# Processing Record 15 of Set 3 | raga
# Processing Record 16 of Set 3 | viedma
# Processing Record 17 of Set 3 | basco
# Processing Record 18 of Set 3 | pocatky
# Processing Record 19 of Set 3 | katsuura
# Processing Record 20 of Set 3 | mar del plata
# Processing Record 21 of Set 3 | yulara
# Processing Record 22 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 3 | batagay-alyta
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | pala
# Processing Record 26 of Set 3 | wentzville
# Processing Record 27 of Set 3 | chokurdakh
# Processing Record 28 of Set 3 | talnakh
# Processing Record 29 of Set 3 | cidreira
# Processing Record 30 of Set 3 | aviles
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | tukrah
# Processing Record 33 of Set 3 | jinchang
# Processing Record 34 of Set 3 | benito juarez
# Processing Record 35 of Set 3 | korla
# Processing Record 36 of Set 3 | vao
# Processing Record 37 of Set 3 | saint george
# Processing Record 38 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 39 of Set 3 | pak phanang
# Processing Record 40 of Set 3 | kedougou
# Processing Record 41 of Set 3 | khani
# Processing Record 42 of Set 3 | sozimskiy
# Processing Record 43 of Set 3 | dikson
# Processing Record 44 of Set 3 | yellowknife
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | vestmannaeyjar
# Processing Record 47 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 3 | bogatyye saby
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | ulladulla
# Processing Record 1 of Set 4 | tolstoy-yurt
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | sinop
# Processing Record 4 of Set 4 | singarayakonda
# Processing Record 5 of Set 4 | tazovskiy
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | iqaluit
# Processing Record 8 of Set 4 | naftah
# City not found. Skipping...
# Processing Record 9 of Set 4 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 4 | san jose
# Processing Record 11 of Set 4 | banjar
# Processing Record 12 of Set 4 | talaya
# Processing Record 13 of Set 4 | yumen
# Processing Record 14 of Set 4 | bridlington
# Processing Record 15 of Set 4 | barroualie
# City not found. Skipping...
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | kristiansund
# Processing Record 18 of Set 4 | serebryansk
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | luanda
# Processing Record 21 of Set 4 | usinsk
# Processing Record 22 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 4 | lata
# Processing Record 24 of Set 4 | shelburne
# Processing Record 25 of Set 4 | xining
# Processing Record 26 of Set 4 | benemerito de las americas
# Processing Record 27 of Set 4 | angoche
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | jejuri
# Processing Record 30 of Set 4 | marsa matruh
# Processing Record 31 of Set 4 | punta cardon
# Processing Record 32 of Set 4 | vaitape
# Processing Record 33 of Set 4 | argentan
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | mehamn
# Processing Record 36 of Set 4 | marsaxlokk
# Processing Record 37 of Set 4 | anuchino
# Processing Record 38 of Set 4 | yaan
# Processing Record 39 of Set 4 | staryy nadym
# Processing Record 40 of Set 4 | dejen
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | inirida
# Processing Record 43 of Set 4 | sydney
# Processing Record 44 of Set 4 | tsabong
# Processing Record 45 of Set 4 | barrow
# Processing Record 46 of Set 4 | xam nua
# Processing Record 47 of Set 4 | hilo
# Processing Record 48 of Set 4 | nichinan
# Processing Record 49 of Set 4 | kodiak
# Processing Record 50 of Set 4 | houma
# Processing Record 1 of Set 5 | beli manastir
# Processing Record 2 of Set 5 | pocao de pedras
# Processing Record 3 of Set 5 | naze
# Processing Record 4 of Set 5 | kraksaan
# Processing Record 5 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 5 | mount isa
# Processing Record 7 of Set 5 | bayir
# Processing Record 8 of Set 5 | north platte
# Processing Record 9 of Set 5 | tuatapere
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | delfzijl
# Processing Record 12 of Set 5 | campbell river
# Processing Record 13 of Set 5 | avarua
# Processing Record 14 of Set 5 | bagdarin
# Processing Record 15 of Set 5 | hovd
# Processing Record 16 of Set 5 | mecca
# Processing Record 17 of Set 5 | dragutesti
# Processing Record 18 of Set 5 | aykhal
# Processing Record 19 of Set 5 | klaksvik
# Processing Record 20 of Set 5 | terbuny
# Processing Record 21 of Set 5 | okha
# Processing Record 22 of Set 5 | banda aceh
# Processing Record 23 of Set 5 | mazatan
# Processing Record 24 of Set 5 | maceio
# Processing Record 25 of Set 5 | kholm
# Processing Record 26 of Set 5 | cherskiy
# Processing Record 27 of Set 5 | shenjiamen
# Processing Record 28 of Set 5 | gondanglegi
# Processing Record 29 of Set 5 | invermere
# Processing Record 30 of Set 5 | vallenar
# Processing Record 31 of Set 5 | tuktoyaktuk
# Processing Record 32 of Set 5 | aklavik
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | znamenskoye
# Processing Record 35 of Set 5 | wagar
# Processing Record 36 of Set 5 | ribeira grande
# Processing Record 37 of Set 5 | arandis
# Processing Record 38 of Set 5 | ventspils
# Processing Record 39 of Set 5 | bosaso
# Processing Record 40 of Set 5 | chiang klang
# Processing Record 41 of Set 5 | coihaique
# Processing Record 42 of Set 5 | baykit
# Processing Record 43 of Set 5 | tailai
# Processing Record 44 of Set 5 | coquimbo
# Processing Record 45 of Set 5 | kununurra
# Processing Record 46 of Set 5 | ponta do sol
# Processing Record 47 of Set 5 | havre-saint-pierre
# Processing Record 48 of Set 5 | matagami
# Processing Record 49 of Set 5 | impfondo
# Processing Record 50 of Set 5 | sisimiut
# Processing Record 1 of Set 6 | miri
# Processing Record 2 of Set 6 | san cristobal
# Processing Record 3 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 4 of Set 6 | evensk
# Processing Record 5 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 6 of Set 6 | clinton
# Processing Record 7 of Set 6 | padang
# Processing Record 8 of Set 6 | mahebourg
# Processing Record 9 of Set 6 | upernavik
# Processing Record 10 of Set 6 | melo
# Processing Record 11 of Set 6 | bubaque
# Processing Record 12 of Set 6 | dvinskoy
# Processing Record 13 of Set 6 | ust-kan
# Processing Record 14 of Set 6 | nesna
# Processing Record 15 of Set 6 | tsienyane
# City not found. Skipping...
# Processing Record 16 of Set 6 | hithadhoo
# Processing Record 17 of Set 6 | khorramshahr
# Processing Record 18 of Set 6 | evansville
# Processing Record 19 of Set 6 | vilhena
# Processing Record 20 of Set 6 | tual
# Processing Record 21 of Set 6 | burica
# City not found. Skipping...
# Processing Record 22 of Set 6 | inhambane
# Processing Record 23 of Set 6 | ambon
# Processing Record 24 of Set 6 | east london
# Processing Record 25 of Set 6 | kinel-cherkassy
# Processing Record 26 of Set 6 | san luis
# Processing Record 27 of Set 6 | vilyuysk
# Processing Record 28 of Set 6 | erenhot
# Processing Record 29 of Set 6 | khatanga
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | qaanaaq
# Processing Record 32 of Set 6 | mme
# City not found. Skipping...
# Processing Record 33 of Set 6 | verkhnevilyuysk
# Processing Record 34 of Set 6 | altamont
# Processing Record 35 of Set 6 | langenburg
# Processing Record 36 of Set 6 | parfenyevo
# Processing Record 37 of Set 6 | ballina
# Processing Record 38 of Set 6 | filadelfia
# Processing Record 39 of Set 6 | bowen
# Processing Record 40 of Set 6 | butaritari
# Processing Record 41 of Set 6 | parker
# Processing Record 42 of Set 6 | marzuq
# Processing Record 43 of Set 6 | bintulu
# Processing Record 44 of Set 6 | kavaratti
# Processing Record 45 of Set 6 | athabasca
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 6 | tiksi
# Processing Record 49 of Set 6 | lompoc
# Processing Record 50 of Set 6 | saint-joseph
# Processing Record 1 of Set 7 | ixtapa
# Processing Record 2 of Set 7 | touros
# Processing Record 3 of Set 7 | inongo
# Processing Record 4 of Set 7 | pokhara
# Processing Record 5 of Set 7 | teguise
# Processing Record 6 of Set 7 | muroto
# Processing Record 7 of Set 7 | praia da vitoria
# Processing Record 8 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 7 | joshimath
# Processing Record 10 of Set 7 | kirakira
# Processing Record 11 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 12 of Set 7 | cisaat
# Processing Record 13 of Set 7 | lakes entrance
# Processing Record 14 of Set 7 | asosa
# Processing Record 15 of Set 7 | lethem
# Processing Record 16 of Set 7 | astipalaia
# City not found. Skipping...
# Processing Record 17 of Set 7 | manaure
# Processing Record 18 of Set 7 | suntar
# Processing Record 19 of Set 7 | margate
# Processing Record 20 of Set 7 | hobyo
# Processing Record 21 of Set 7 | tilik
# Processing Record 22 of Set 7 | luderitz
# Processing Record 23 of Set 7 | vila
# Processing Record 24 of Set 7 | hasaki
# Processing Record 25 of Set 7 | bambanglipuro
# Processing Record 26 of Set 7 | porto novo
# Processing Record 27 of Set 7 | marshall
# Processing Record 28 of Set 7 | lorengau
# Processing Record 29 of Set 7 | ishinomaki
# Processing Record 30 of Set 7 | pierre
# Processing Record 31 of Set 7 | cabo rojo
# Processing Record 32 of Set 7 | ossora
# Processing Record 33 of Set 7 | severo-kurilsk
# Processing Record 34 of Set 7 | ilhabela
# Processing Record 35 of Set 7 | nouadhibou
# Processing Record 36 of Set 7 | vestmanna
# Processing Record 37 of Set 7 | takhtamygda
# Processing Record 38 of Set 7 | chulym
# Processing Record 39 of Set 7 | batamshinskiy
# Processing Record 40 of Set 7 | poum
# Processing Record 41 of Set 7 | panaba
# Processing Record 42 of Set 7 | abha
# Processing Record 43 of Set 7 | morondava
# Processing Record 44 of Set 7 | paamiut
# Processing Record 45 of Set 7 | qaqortoq
# Processing Record 46 of Set 7 | carutapera
# Processing Record 47 of Set 7 | snezhnogorsk
# Processing Record 48 of Set 7 | yerbogachen
# Processing Record 49 of Set 7 | nome
# Processing Record 50 of Set 7 | ovsyanka
# Processing Record 1 of Set 8 | soteapan
# Processing Record 2 of Set 8 | bacuit
# City not found. Skipping...
# Processing Record 3 of Set 8 | loknya
# Processing Record 4 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 8 | arraial do cabo
# Processing Record 6 of Set 8 | pinawa
# Processing Record 7 of Set 8 | durham
# Processing Record 8 of Set 8 | christchurch
# Processing Record 9 of Set 8 | kihei
# Processing Record 10 of Set 8 | alofi
# Processing Record 11 of Set 8 | norman wells
# Processing Record 12 of Set 8 | vostok
# Processing Record 13 of Set 8 | gat
# Processing Record 14 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 15 of Set 8 | chachapoyas
# Processing Record 16 of Set 8 | fairbanks
# Processing Record 17 of Set 8 | sawtell
# Processing Record 18 of Set 8 | andilamena
# Processing Record 19 of Set 8 | teguldet
# Processing Record 20 of Set 8 | the valley
# Processing Record 21 of Set 8 | ponta delgada
# Processing Record 22 of Set 8 | margahovit
# Processing Record 23 of Set 8 | marrakesh
# Processing Record 24 of Set 8 | wawa
# Processing Record 25 of Set 8 | tommot
# Processing Record 26 of Set 8 | gayeri
# Processing Record 27 of Set 8 | los llanos de aridane
# Processing Record 28 of Set 8 | panjab
# Processing Record 29 of Set 8 | lebu
# Processing Record 30 of Set 8 | olafsvik
# Processing Record 31 of Set 8 | laguna
# Processing Record 32 of Set 8 | port shepstone
# Processing Record 33 of Set 8 | fonte boa
# Processing Record 34 of Set 8 | ketchikan
# Processing Record 35 of Set 8 | geraldton
# Processing Record 36 of Set 8 | zhangye
# Processing Record 37 of Set 8 | dzhalil
# Processing Record 38 of Set 8 | novyy urengoy
# Processing Record 39 of Set 8 | kruisfontein
# Processing Record 40 of Set 8 | bogorodskoye
# Processing Record 41 of Set 8 | pontianak
# Processing Record 42 of Set 8 | boda
# Processing Record 43 of Set 8 | dezful
# Processing Record 44 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 8 | pangnirtung
# Processing Record 46 of Set 8 | zabid
# Processing Record 47 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 8 | kaeo
# Processing Record 49 of Set 8 | setermoen
# Processing Record 50 of Set 8 | tomatlan
# Processing Record 1 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 9 | sabana de torres
# Processing Record 3 of Set 9 | antofagasta
# Processing Record 4 of Set 9 | sabibah
# City not found. Skipping...
# Processing Record 5 of Set 9 | luganville
# Processing Record 6 of Set 9 | sinnamary
# Processing Record 7 of Set 9 | nabire
# Processing Record 8 of Set 9 | diamantino
# Processing Record 9 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 10 of Set 9 | lancaster
# Processing Record 11 of Set 9 | zhigansk
# Processing Record 12 of Set 9 | ciudad bolivar
# Processing Record 13 of Set 9 | camacha
# Processing Record 14 of Set 9 | zhongshu
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | wukari
# Processing Record 17 of Set 9 | mushie
# Processing Record 18 of Set 9 | viru
# Processing Record 19 of Set 9 | keuruu
# Processing Record 20 of Set 9 | sobolevo
# Processing Record 21 of Set 9 | dubrovka
# Processing Record 22 of Set 9 | reconquista
# Processing Record 23 of Set 9 | miranda
# Processing Record 24 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 25 of Set 9 | chunhuhub
# Processing Record 26 of Set 9 | ahar
# Processing Record 27 of Set 9 | paramonga
# Processing Record 28 of Set 9 | hitoyoshi
# Processing Record 29 of Set 9 | gamba
# Processing Record 30 of Set 9 | ahuimanu
# Processing Record 31 of Set 9 | andalan
# Processing Record 32 of Set 9 | sar-e pul
# Processing Record 33 of Set 9 | aberdeen
# Processing Record 34 of Set 9 | maragogi
# Processing Record 35 of Set 9 | kedrovyy
# Processing Record 36 of Set 9 | norashen
# Processing Record 37 of Set 9 | victoria
# Processing Record 38 of Set 9 | davila
# Processing Record 39 of Set 9 | roald
# Processing Record 40 of Set 9 | kropotkin
# Processing Record 41 of Set 9 | saint-augustin
# Processing Record 42 of Set 9 | chipinge
# Processing Record 43 of Set 9 | payson
# Processing Record 44 of Set 9 | awbari
# Processing Record 45 of Set 9 | lavrentiya
# Processing Record 46 of Set 9 | xushan
# Processing Record 47 of Set 9 | puerto quijarro
# Processing Record 48 of Set 9 | pogar
# Processing Record 49 of Set 9 | bjelovar
# Processing Record 50 of Set 9 | wad madani
# Processing Record 1 of Set 10 | honiara
# Processing Record 2 of Set 10 | salalah
# Processing Record 3 of Set 10 | muncar
# Processing Record 4 of Set 10 | meadow lake
# Processing Record 5 of Set 10 | tabuk
# Processing Record 6 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 7 of Set 10 | xadani
# City not found. Skipping...
# Processing Record 8 of Set 10 | terney
# Processing Record 9 of Set 10 | cabo san lucas
# Processing Record 10 of Set 10 | kilindoni
# Processing Record 11 of Set 10 | berlevag
# Processing Record 12 of Set 10 | lucea
# Processing Record 13 of Set 10 | makakilo city
# Processing Record 14 of Set 10 | omboue
# Processing Record 15 of Set 10 | eureka
# Processing Record 16 of Set 10 | muhos
# Processing Record 17 of Set 10 | hamilton
# Processing Record 18 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 10 | leirvik
# Processing Record 20 of Set 10 | cao bang
# Processing Record 21 of Set 10 | jati
# Processing Record 22 of Set 10 | klyuchevskiy
# Processing Record 23 of Set 10 | iracoubo
# Processing Record 24 of Set 10 | belmonte
# Processing Record 25 of Set 10 | male
# Processing Record 26 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 10 | hella
# Processing Record 28 of Set 10 | coos bay
# Processing Record 29 of Set 10 | juegang
# Processing Record 30 of Set 10 | sheltozero
# Processing Record 31 of Set 10 | dawei
# Processing Record 32 of Set 10 | lakhna
# Processing Record 33 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 10 | upington
# Processing Record 35 of Set 10 | hazorasp
# Processing Record 36 of Set 10 | anadyr
# Processing Record 37 of Set 10 | swan hill
# Processing Record 38 of Set 10 | gigmoto
# Processing Record 39 of Set 10 | seddon
# Processing Record 40 of Set 10 | kortkeros
# Processing Record 41 of Set 10 | taguatinga
# Processing Record 42 of Set 10 | shimoda
# Processing Record 43 of Set 10 | ahipara
# Processing Record 44 of Set 10 | praia
# Processing Record 45 of Set 10 | tabory
# Processing Record 46 of Set 10 | whitehorse
# Processing Record 47 of Set 10 | havoysund
# Processing Record 48 of Set 10 | flinders
# Processing Record 49 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 10 | honningsvag
# Processing Record 1 of Set 11 | uige
# Processing Record 2 of Set 11 | tiznit
# Processing Record 3 of Set 11 | takoradi
# Processing Record 4 of Set 11 | san francisco
# Processing Record 5 of Set 11 | leningradskiy
# Processing Record 6 of Set 11 | opole
# Processing Record 7 of Set 11 | gurskoye
# City not found. Skipping...
# Processing Record 8 of Set 11 | hoi an
# Processing Record 9 of Set 11 | chapais
# Processing Record 10 of Set 11 | killybegs
# Processing Record 11 of Set 11 | sundumbili
# Processing Record 12 of Set 11 | umm bab
# Processing Record 13 of Set 11 | puerto cabezas
# Processing Record 14 of Set 11 | colombo
# Processing Record 15 of Set 11 | uyovu
# Processing Record 16 of Set 11 | shubarkuduk
# Processing Record 17 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 19 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 11 | bilma
# Processing Record 21 of Set 11 | amarante do maranhao
# Processing Record 22 of Set 11 | clyde river
# Processing Record 23 of Set 11 | lanxi
# Processing Record 24 of Set 11 | great yarmouth
# Processing Record 25 of Set 11 | qax
# Processing Record 26 of Set 11 | manta
# Processing Record 27 of Set 11 | goderich
# Processing Record 28 of Set 11 | colesberg
# Processing Record 29 of Set 11 | karratha
# Processing Record 30 of Set 11 | hue
# Processing Record 31 of Set 11 | dunedin
# Processing Record 32 of Set 11 | bud
# Processing Record 33 of Set 11 | bonavista
# Processing Record 34 of Set 11 | kurchum
# Processing Record 35 of Set 11 | provideniya
# Processing Record 36 of Set 11 | mekhe
# Processing Record 37 of Set 11 | portland
# Processing Record 38 of Set 11 | kuressaare
# Processing Record 39 of Set 11 | bend
# Processing Record 40 of Set 11 | baruun-urt
# Processing Record 41 of Set 11 | phuket
# Processing Record 42 of Set 11 | gayny
# Processing Record 43 of Set 11 | gol
# Processing Record 44 of Set 11 | ekhabi
# Processing Record 45 of Set 11 | flin flon
# Processing Record 46 of Set 11 | kahului
# Processing Record 47 of Set 11 | uniontown
# Processing Record 48 of Set 11 | lillesand
# Processing Record 49 of Set 11 | cayenne
# Processing Record 50 of Set 11 | alugan
# Processing Record 1 of Set 12 | yasnyy
# Processing Record 2 of Set 12 | grindavik
# Processing Record 3 of Set 12 | talavera de la reina
# Processing Record 4 of Set 12 | lasa
# Processing Record 5 of Set 12 | avera
# Processing Record 6 of Set 12 | jand
# Processing Record 7 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 12 | saint-georges
# Processing Record 9 of Set 12 | erdenet
# Processing Record 10 of Set 12 | kushiro
# Processing Record 11 of Set 12 | jacareacanga
# Processing Record 12 of Set 12 | santa cruz de tenerife
# Processing Record 13 of Set 12 | kieta
# Processing Record 14 of Set 12 | svetlyy
# Processing Record 15 of Set 12 | makanya
# Processing Record 16 of Set 12 | namibe
# Processing Record 17 of Set 12 | narasannapeta
# Processing Record 18 of Set 12 | williams lake
# Processing Record 19 of Set 12 | oda
# Processing Record 20 of Set 12 | mandurah
# Processing Record 21 of Set 12 | north bend
# Processing Record 22 of Set 12 | ginir
# Processing Record 23 of Set 12 | dessalines
# Processing Record 24 of Set 12 | puerto varas
# Processing Record 25 of Set 12 | hinton
# Processing Record 26 of Set 12 | valenca
# Processing Record 27 of Set 12 | candido mendes
# Processing Record 28 of Set 12 | goudomp
# City not found. Skipping...
# Processing Record 29 of Set 12 | port hedland
# Processing Record 30 of Set 12 | saint anthony
# Processing Record 31 of Set 12 | moiyabana
# City not found. Skipping...
# Processing Record 32 of Set 12 | saint-pierre
# Processing Record 33 of Set 12 | shahrud
# Processing Record 34 of Set 12 | reriutaba
# Processing Record 35 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 12 | xiangdong
# City not found. Skipping...
# Processing Record 37 of Set 12 | beckley
# Processing Record 38 of Set 12 | belaya gora
# Processing Record 39 of Set 12 | roblin
# Processing Record 40 of Set 12 | edwardsville
# Processing Record 41 of Set 12 | alamogordo
# Processing Record 42 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 43 of Set 12 | xuddur
# Processing Record 44 of Set 12 | shakawe
# Processing Record 45 of Set 12 | zavetnoye
# Processing Record 46 of Set 12 | ostrovnoy
# Processing Record 47 of Set 12 | xai-xai
# Processing Record 48 of Set 12 | san quintin
# Processing Record 49 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 50 of Set 12 | sabzevar
# Processing Record 1 of Set 13 | uvalde
# Processing Record 2 of Set 13 | nizhnyaya tavda
# Processing Record 3 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 4 of Set 13 | loa janan
# Processing Record 5 of Set 13 | ostersund
# Processing Record 6 of Set 13 | nantucket
# Processing Record 7 of Set 13 | yurla
# Processing Record 8 of Set 13 | asau
# Processing Record 9 of Set 13 | gewane
# Processing Record 10 of Set 13 | mehran
# Processing Record 11 of Set 13 | esso
# Processing Record 12 of Set 13 | dalvik
# Processing Record 13 of Set 13 | buala
# Processing Record 14 of Set 13 | dawlatabad
# Processing Record 15 of Set 13 | ulaangom
# Processing Record 16 of Set 13 | enid
# Processing Record 17 of Set 13 | sur
# Processing Record 18 of Set 13 | sherman
# Processing Record 19 of Set 13 | mombetsu
# Processing Record 20 of Set 13 | henties bay
# Processing Record 21 of Set 13 | paita
# Processing Record 22 of Set 13 | faya
# Processing Record 23 of Set 13 | lindi
# Processing Record 24 of Set 13 | brindisi
# Processing Record 25 of Set 13 | taoudenni
# Processing Record 26 of Set 13 | nemuro
# Processing Record 27 of Set 13 | nizip
# Processing Record 28 of Set 13 | sosnogorsk
# Processing Record 29 of Set 13 | jardim
# Processing Record 30 of Set 13 | boyolangu
# Processing Record 31 of Set 13 | pisco
# Processing Record 32 of Set 13 | nelson bay
# Processing Record 33 of Set 13 | khorixas
# Processing Record 34 of Set 13 | cabra
# Processing Record 35 of Set 13 | santa maria
# Processing Record 36 of Set 13 | olaine
# Processing Record 37 of Set 13 | tautira
# Processing Record 38 of Set 13 | bolobo
# Processing Record 39 of Set 13 | kapuvar
# Processing Record 40 of Set 13 | yamada
# Processing Record 41 of Set 13 | ola
# Processing Record 42 of Set 13 | masuguru
# Processing Record 43 of Set 13 | sechura
# Processing Record 44 of Set 13 | berbera
# Processing Record 45 of Set 13 | kozluk
# Processing Record 46 of Set 13 | paracuru
# Processing Record 47 of Set 13 | cabedelo
# Processing Record 48 of Set 13 | aksu
# Processing Record 49 of Set 13 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 50 of Set 13 | konstantinovka
# Processing Record 1 of Set 14 | quelimane
# Processing Record 2 of Set 14 | nova borova
# Processing Record 3 of Set 14 | sars
# Processing Record 4 of Set 14 | bac lieu
# Processing Record 5 of Set 14 | lovozero
# Processing Record 6 of Set 14 | barao de melgaco
# Processing Record 7 of Set 14 | auki
# Processing Record 8 of Set 14 | moerai
# Processing Record 9 of Set 14 | irgakly
# Processing Record 10 of Set 14 | sokoto
# Processing Record 11 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 14 | pushkino
# Processing Record 13 of Set 14 | balkanabat
# Processing Record 14 of Set 14 | potsdam
# Processing Record 15 of Set 14 | peterhead
# Processing Record 16 of Set 14 | sydney mines
# Processing Record 17 of Set 14 | elizabeth city
# Processing Record 18 of Set 14 | nyagan
# Processing Record 19 of Set 14 | mountain home
# Processing Record 20 of Set 14 | tete
# Processing Record 21 of Set 14 | onega
# Processing Record 22 of Set 14 | peruibe
# Processing Record 23 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 14 | keetmanshoop
# Processing Record 25 of Set 14 | mizdah
# Processing Record 26 of Set 14 | kalmunai
# Processing Record 27 of Set 14 | itum-kale
# Processing Record 28 of Set 14 | grande-riviere
# City not found. Skipping...
# Processing Record 29 of Set 14 | costinesti
# Processing Record 30 of Set 14 | ketchenery
# City not found. Skipping...
# Processing Record 31 of Set 14 | vidalia
# Processing Record 32 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 33 of Set 14 | shido
# Processing Record 34 of Set 14 | bangil
# Processing Record 35 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 36 of Set 14 | andenes
# Processing Record 37 of Set 14 | tura
# Processing Record 38 of Set 14 | ramnagar
# Processing Record 39 of Set 14 | khvastovichi
# Processing Record 40 of Set 14 | oriximina
# Processing Record 41 of Set 14 | yenagoa
# Processing Record 42 of Set 14 | port-gentil
# Processing Record 43 of Set 14 | hualmay
# Processing Record 44 of Set 14 | pemba
# Processing Record 45 of Set 14 | lincoln
# Processing Record 46 of Set 14 | marsh harbour
# Processing Record 47 of Set 14 | erzin
# Processing Record 48 of Set 14 | maroantsetra
# Processing Record 49 of Set 14 | indramayu
# Processing Record 50 of Set 14 | santa isabel
# Processing Record 1 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 2 of Set 15 | visnes
# Processing Record 3 of Set 15 | hengyang
# Processing Record 4 of Set 15 | camacupa
# Processing Record 5 of Set 15 | florence
# Processing Record 6 of Set 15 | mingshui
# Processing Record 7 of Set 15 | murashi
# Processing Record 8 of Set 15 | mabai
# Processing Record 9 of Set 15 | saint-leu
# Processing Record 10 of Set 15 | izamal
# Processing Record 11 of Set 15 | nuuk
# Processing Record 12 of Set 15 | nha trang
# Processing Record 13 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 14 of Set 15 | druzhba
# Processing Record 15 of Set 15 | stornoway
# Processing Record 16 of Set 15 | krasnoshchekovo
# Processing Record 17 of Set 15 | mnogovershinnyy
# Processing Record 18 of Set 15 | rawson
# Processing Record 19 of Set 15 | chulman
# Processing Record 20 of Set 15 | hofn
# Processing Record 21 of Set 15 | krasnorechenskiy
# Processing Record 22 of Set 15 | kissidougou
# Processing Record 23 of Set 15 | angelholm
# City not found. Skipping...
# Processing Record 24 of Set 15 | tamiahua
# Processing Record 25 of Set 15 | dhangadhi
# Processing Record 26 of Set 15 | pawai
# Processing Record 27 of Set 15 | nokaneng
# Processing Record 28 of Set 15 | novobureyskiy
# Processing Record 29 of Set 15 | qasigiannguit
# Processing Record 30 of Set 15 | garden city
# Processing Record 31 of Set 15 | verkhniy ufaley
# Processing Record 32 of Set 15 | tuy hoa
# Processing Record 33 of Set 15 | mapiripan
# Processing Record 34 of Set 15 | port augusta
# Processing Record 35 of Set 15 | vikulovo
# Processing Record 36 of Set 15 | mahibadhoo
# Processing Record 37 of Set 15 | beloha
# Processing Record 38 of Set 15 | jiuquan
# Processing Record 39 of Set 15 | tilichiki
# Processing Record 40 of Set 15 | fukue
# Processing Record 41 of Set 15 | cacule
# Processing Record 42 of Set 15 | iquitos
# Processing Record 43 of Set 15 | otawara
# Processing Record 44 of Set 15 | lumberton
# Processing Record 45 of Set 15 | melville
# Processing Record 46 of Set 15 | bilibino
# Processing Record 47 of Set 15 | sorong
# Processing Record 48 of Set 15 | puri
# Processing Record 49 of Set 15 | naziya
# Processing Record 50 of Set 15 | burnie
# Processing Record 1 of Set 16 | mugur-aksy
# Processing Record 2 of Set 16 | kupang
# Processing Record 3 of Set 16 | mango
# Processing Record 4 of Set 16 | fevralsk
# City not found. Skipping...
# Processing Record 5 of Set 16 | zavolzhsk
# Processing Record 6 of Set 16 | sorland
# Processing Record 7 of Set 16 | grand-lahou
# Processing Record 8 of Set 16 | santa rosa
# Processing Record 9 of Set 16 | daru
# Processing Record 10 of Set 16 | jalu
# Processing Record 11 of Set 16 | manicore
# Processing Record 12 of Set 16 | taltal
# Processing Record 13 of Set 16 | tombouctou
# Processing Record 14 of Set 16 | okandja
# City not found. Skipping...
# Processing Record 15 of Set 16 | gizo
# Processing Record 16 of Set 16 | adrar
# Processing Record 17 of Set 16 | urumqi
# Processing Record 18 of Set 16 | kang
# Processing Record 19 of Set 16 | butterworth
# Processing Record 20 of Set 16 | bhawanipatna
# Processing Record 21 of Set 16 | linxia
# Processing Record 22 of Set 16 | tabou
# Processing Record 23 of Set 16 | acolla
# Processing Record 24 of Set 16 | neya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Bluff      NZ -46.6000  168.3333     44.80        84
# 1         Jamestown      US  42.0970  -79.2353     71.10        68
# 2           Hakkari      TR  37.5833   44.1667     55.65        45
# 3        Bredasdorp      ZA -34.5322   20.0403     50.29        87
# 4            Atuona      PF  -9.8000 -139.0333     77.56        74
# 5          Hermanus      ZA -34.4187   19.2345     54.90        71
# 6         Cape Town      ZA -33.9258   18.4232     57.27        55
# 7        Nikolskoye      RU  59.7035   30.7861     50.40        85
# 8   Bambous Virieux      MU -20.3428   57.7575     72.21        88
# 9  Sao Luiz Gonzaga      BR -28.4083  -54.9608     65.97        91
#
#    Cloudiness  Wind Speed           Description
# 0         100       23.20  heavy intensity rain
# 1          90        5.99                  mist
# 2           0        6.17             clear sky
# 3          13        0.00            few clouds
# 4          15       17.78            few clouds
# 5          37        7.11      scattered clouds
# 6          20       12.66            few clouds
# 7           0        6.71             clear sky
# 8          75       13.80         broken clouds
# 9          99       12.35       overcast clouds

# %%
#reorder columns as City, County, Data, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed
new_column_order = ["City","Country","Lat","Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

#assign city_dat with new column order

city_data_df= city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
